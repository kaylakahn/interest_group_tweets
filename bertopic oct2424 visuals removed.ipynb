# %%
import os
import pandas as pd
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
import torch
import numpy as np
from bertopic.representation import MaximalMarginalRelevance
from sklearn.feature_extraction.text import CountVectorizer
import copy

# %%
# load positives df, see how many are scored between .5 and .7
os.chdir('/data/kayla_data')
df = pd.read_csv('classified_positives_missingtweetsincluded_oct2424.csv', low_memory=False)
df = df[['tweet_id', 'text','predicted_label', 'score','predicted_label_numeric','user_id']]
print(df['score'].between(.5,.7).sum()/len(df)) 
print(df['score'].between(.9,1).sum()/len(df))
# Out:
# 0.08014234093126142
# 0.7905302978259575

# %%
df.head()
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0            tweet_id  \
# 0             0             0           0  954588503677001729
# 1             1             1           1  954550807025897473
# 2             2             2           2  954549999290978304
# 3             3             3           3  953700349885509633
# 4             4             4           4  951144066426777600
#
#                                                 text   predicted_label  \
# 0  .@RepRichmond: "…[Republicans] are unable to g...  takes a position
# 1  Are you fired up by the #TrumpShutdown? Are yo...  takes a position
# 2  Democrats are holding strong to say: #GOP cont...  takes a position
# 3  Today, three quarters of all immigrants to the...  takes a position
# 4  Starting today, I'm asking nominees to our cou...  takes a position
#
#       score  Unnamed: 0.1  user_id created_at_day created_at_time  \
# 0  0.999771           NaN      NaN            NaN             NaN
# 1  0.999710           NaN      NaN            NaN             NaN
# 2  0.999847           NaN      NaN            NaN             NaN
# 3  0.999444           NaN      NaN            NaN             NaN
# 4  0.991061           NaN      NaN            NaN             NaN
#
#   user_screen_name             favorite_count  retweet_count  \
# 0              NaN                        NaN            NaN
# 1              NaN                        NaN            NaN
# 2              NaN                        NaN            NaN
# 3              NaN                        NaN            NaN
# 4              NaN                        NaN            NaN
#
#    predicted_label_numeric
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1

# %% [markdown]
# # Topic modeling with bertopic

# %%
# preprocess - remove RT @s at the start of tweets so it doesn't become a topic, remove urls
df['text'] = df['text'].str.replace(r'RT @', '', regex=True)
df['text'] = df['text'].str.replace(r'http\S+|www.\S+', '', regex=True)

# %% [markdown]
# get embeddings first so can load them (instead of rerunning them) in case of error.

# %%
docs = df['text'].tolist()
print(torch.backends.mps.is_available())
sentence_model = SentenceTransformer("all-MiniLM-L6-v2", device = 'mps')
#embeddings = sentence_model.encode(docs, show_progress_bar=True)
#np.save('bertopic_new_oct2424/embeddings_oct2424_noRTnoHTTP.npy', embeddings)
# Out:
# True
# Batches:   0%|          | 0/13647 [00:00<?, ?it/s]

# %%
# import the embeddings if needed
embeddings = np.load('bertopic_new_oct2424/embeddings_oct2424_noRTnoHTTP.npy')

# %% [markdown]
# Initial training of the model

# %%
# mmr at higher levels will put more diverse words together in a topic (range 0-1)
representation_model = MaximalMarginalRelevance(diversity=0.5)
vectorizer_model = CountVectorizer(stop_words="english")
topic_model = BERTopic(embedding_model=sentence_model, 
                       representation_model=representation_model, 
                       vectorizer_model = vectorizer_model,
                       n_gram_range=(1,3),
                       min_topic_size=300)
# if issue with frequent words that aren't stop words: ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# %% [markdown]
# initial application of the model

# %%
topics, probs = topic_model.fit_transform(docs, embeddings)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
topic_model.save("bertopic_new_oct2424/topic models_soct2424", serialization="safetensors", save_ctfidf=True)

# %% [markdown]
# explore initial topics before doing any sort of reduction

# %%
print(topic_model.get_topic_info())
print(topic_model.get_topic(-1))
# Out:
#      Topic   Count                                               Name  \
# 0       -1  160557                 -1_workers_vote_healthcare_twitter
# 1        0   15877                       0_prolife_abortions_born_roe
# 2        1   13394                   1_educators_public_redfored_debt
# 3        2   12652                      2_lgbtq_hrc_trans_equalityact
# 4        3   10546                3_climatechange_epa_emissions_green
# ..     ...     ...                                                ...
# 160    159     317                       159_culinary226_union_las_nv
# 161    160     314                160_phit_thesfia_fitness_inactivity
# 162    161     309  161_nasw_socialwork_socialworkmonth_socialwork...
# 163    162     304  162_geriatrics_amergeriatrics_seniors_olderadults
# 164    163     303             163_licenses_ohio_freedomtowork_reform
#
#                                         Representation  \
# 0    [workers, vote, healthcare, twitter, tax, cong...
# 1    [prolife, abortions, born, roe, sbalist, marjo...
# 2    [educators, public, redfored, debt, devos, bet...
# 3    [lgbtq, hrc, trans, equalityact, discriminatio...
# 4    [climatechange, epa, emissions, green, renewab...
# ..                                                 ...
# 160  [culinary226, union, las, nv, knocking, hospit...
# 161  [phit, thesfia, fitness, inactivity, act, than...
# 162  [nasw, socialwork, socialworkmonth, socialwork...
# 163  [geriatrics, amergeriatrics, seniors, olderadu...
# 164  [licenses, ohio, freedomtowork, reform, barrie...
#
#                                    Representative_Docs
# 0    [Access to health care is a life or death issu...
# 1    ["I became an abortion provider because aborti...
# 2    [.@rweingarten: Teachers want to go back to sc...
# 3    [.@HRC thanks our pro-equality majority in the...
# 4    [The Climate Superheroes We Need  #environment...
# ..                                                 ...
# 160  [Culinary226: Together, working people are on ...
# 161               [#PassPHIT , #PassPHIT , #PassPHIT ]
# 162  [#socialworkers #nasw urges you to take action...
# 163  [We can all support #geriatrics! Contact your ...
# 164  [How occupational licensing is hurting America...
#
# [165 rows x 5 columns]
# [('workers', 0.004997537798522661), ('vote', 0.004316916962760284), ('healthcare', 0.004284052844646016), ('twitter', 0.00407801159615062), ('tax', 0.003882891639946362), ('congress', 0.003689901271384015), ('union', 0.0036839790928993336), ('rights', 0.0036413682118483313), ('today', 0.0036003778956489717), ('families', 0.00350003327403254)]

# %% [markdown]
# ## reduce number of topics

# %%
# reduce topics to 50
topic_model_50 = copy.deepcopy(topic_model)
topic_model_50.reduce_topics(docs, nr_topics=50)
topic_model_50.get_topic_info()
# Out:
#     Topic   Count                                               Name  \
# 0      -1  160557                   -1_workers_twitter_trump_support
# 1       0   43573              0_medicareforall_opioid_nurses_prices
# 2       1   25590           1_climate_infrastructure_spending_change
# 3       2   23660                            2_abortion_pro_hyde_roe
# 4       3   19424                 3_covid19_pandemic_coronavirus_hiv
# 5       4   15747             4_lgbtq_hrc_discrimination_equalityact
# 6       5   13394                5_educators_public_rweingarten_loan
# 7       6   11632         6_veterans_thank_roseanndemoro_dcstatehood
# 8       7   11335                7_kavanaugh_judges_barrett_nominees
# 9       8    9240              8_immigration_children_2020census_tps
# 10      9    9084             9_socialsecurity_benefits_medicare_ssi
# 11     10    8597                           10_taxes_cuts_reform_gop
# 12     11    8065                  11_civil_doj_gunviolence_attorney
# 13     12    7539                  12_ballot_suppression_sure_rights
# 14     13    7337            13_unions_working_marriottstrike_strike
# 15     14    7089            14_unemployment_snap_families_childcare
# 16     15    6186                  15_cigarettes_vaping_kids_menthol
# 17     16    4419                 16_daca_dreamers_dreamact_congress
# 18     17    4029              17_naacp_hate_justice_charlottesville
# 19     18    3712                 18_tariffs_nafta_aluminum_american
# 20     19    3192           19_diplomacy_aumf_irandeal_yemencantwait
# 21     20    3035     20_amacforamerica_democracy_media_rcharles4usa
# 22     21    2402                    21_wage_minimum_15_raisethewage
# 23     22    2376                 22_netneutrality_fcc_neutrality_5g
# 24     23    2286              23_muslimban_ban_trump_rightwingwatch
# 25     24    2238  24_advocateforarthritis_disability_arthritisfd...
# 26     25    1798             25_medical_tax_repealdevicetax_devices
# 27     26    1702             26_wearealpa_workers_catering_airlines
# 28     27    1477                  27_masks_spread_customers_covid19
# 29     28    1387                         28_gag_rule_titlex_assault
# 30     29    1385              29_texans_caring_leadership_hospitals
# 31     30    1317              30_publiccharge_rule_billing_proposed
# 32     31    1195              31_fight4her_endalz_honor_reprorights
# 33     32    1148                     32_goptaxbill_tax_twitter_cuts
# 34     33    1126                  33_puerto_hurricane_maria_schools
# 35     34     988        34_investigation_trump_fbi_impeachmenttrial
# 36     35     931         35_usps_savethepostoffice_postmaster_louis
# 37     36     860                   36_pork_pigbook_wasteful_earmark
# 38     37     850            37_employers_commitment_supporting_grow
# 39     38     698                  38_sportsbetting_stadiums_ban_aga
# 40     39     580   39_euthanasia_physician_canada_suicideprevention
# 41     40     560                40_ntu_coalition_urges_freedomworks
# 42     41     513                                41_los_para_una_más
# 43     42     458                      42_usmca_mexico_jobs_ranchers
# 44     43     365          43_autocareorg_drivesafeact_data_trucking
# 45     44     354                     44_lilly_hhsgov_insulin_pharma
# 46     45     334                       45_atr_coalition_act_opposes
# 47     46     317                        46_culinary226_union_las_nv
# 48     47     314              47_passphit_phitday17_thesfia_fitness
# 49     48     303            48_licenses_ohio_freedomtowork_barriers
#
#                                        Representation  \
# 0   [workers, twitter, trump, support, congress, h...
# 1   [medicareforall, opioid, nurses, prices, obama...
# 2   [climate, infrastructure, spending, change, ca...
# 3   [abortion, pro, hyde, roe, amendment, right, s...
# 4   [covid19, pandemic, coronavirus, hiv, vaccines...
# 5   [lgbtq, hrc, discrimination, equalityact, penc...
# 6   [educators, public, rweingarten, loan, redfore...
# 7   [veterans, thank, roseanndemoro, dcstatehood, ...
# 8   [kavanaugh, judges, barrett, nominees, courtsm...
# 9   [immigration, children, 2020census, tps, asylu...
# 10  [socialsecurity, benefits, medicare, ssi, expa...
# 11  [taxes, cuts, reform, gop, salt, class, wealth...
# 12  [civil, doj, gunviolence, attorney, gupta, van...
# 13  [ballot, suppression, sure, rights, voice, tod...
# 14  [unions, working, marriottstrike, strike, miss...
# 15  [unemployment, snap, families, childcare, paid...
# 16  [cigarettes, vaping, kids, menthol, juul, fda,...
# 17  [daca, dreamers, dreamact, congress, recipient...
# 18  [naacp, hate, justice, charlottesville, blackl...
# 19  [tariffs, nafta, aluminum, american, 232, mexi...
# 20  [diplomacy, aumf, irandeal, yemencantwait, 200...
# 21  [amacforamerica, democracy, media, rcharles4us...
# 22  [wage, minimum, 15, raisethewage, fightfor15, ...
# 23  [netneutrality, fcc, neutrality, 5g, data, cab...
# 24  [muslimban, ban, trump, rightwingwatch, libert...
# 25  [advocateforarthritis, disability, arthritisfd...
# 26  [medical, tax, repealdevicetax, devices, cadil...
# 27  [wearealpa, workers, catering, airlines, front...
# 28  [masks, spread, customers, covid19, mandate, d...
# 29  [gag, rule, titlex, assault, ix, survivors, no...
# 30  [texans, caring, leadership, hospitals, trauma...
# 31  [publiccharge, rule, billing, proposed, protec...
# 32  [fight4her, endalz, honor, reprorights, popcon...
# 33  [goptaxbill, tax, twitter, cuts, medicare, fam...
# 34  [puerto, hurricane, maria, schools, rweingarte...
# 35  [investigation, trump, fbi, impeachmenttrial, ...
# 36  [usps, savethepostoffice, postmaster, louis, g...
# 37  [pork, pigbook, wasteful, earmark, govwaste, s...
# 38  [employers, commitment, supporting, grow, taxr...
# 39  [sportsbetting, stadiums, ban, aga, paspa, geo...
# 40  [euthanasia, physician, canada, suicideprevent...
# 41  [ntu, coalition, urges, freedomworks, protecta...
# 42  [los, para, una, más, mamasconpoder, familias,...
# 43  [usmca, mexico, jobs, ranchers, exports, marke...
# 44  [autocareorg, drivesafeact, data, trucking, yo...
# 45  [lilly, hhsgov, insulin, pharma, exec, alexaza...
# 46  [atr, coalition, act, opposes, lawmakers, simp...
# 47  [culinary226, union, las, nv, vote, hospitalit...
# 48  [passphit, phitday17, thesfia, fitness, inacti...
# 49  [licenses, ohio, freedomtowork, barriers, ohfo...
#
#                                   Representative_Docs
# 0   [The opportunity to join a union—no matter whe...
# 1   [Thanks to the ACA's #Medicaid expansion, thou...
# 2   [If @JoeBiden's $4 trillion infrastructure pac...
# 3   [For those who claim Planned Parenthood isn't ...
# 4   [COVID-19 has disproportionately impacted comm...
# 5   [AlphonsoDavid: For far too long, anti-LGBTQ p...
# 6   [AFSCME: We stand in solidarity with over 30,0...
# 7   [As veterans, we dedicated our lives to this c...
# 8   [An increasing number of Americans don't want ...
# 9   [Immigration has been a major topic of debate ...
# 10  [Social Security is more important than ever. ...
# 11  [Making the Tax Code Great Again  #taxreform, ...
# 12  [The Senate needs to immediately confirm Krist...
# 13  [🚨GEORGIA🚨 We've got just 20 days until electi...
# 14  [We won’t stop fighting until all working peop...
# 15  [Everyone should have food on the table. The 3...
# 16  [After years of Big Tobacco marketing flavored...
# 17  [#DACA recipients are members of our communiti...
# 18  [Today and every day, we stand with the global...
# 19  [Don't believe everything you read about trade...
# 20  [The U.S. has to open up to #diplomacy with #N...
# 21  [#AMACforAmerica , #AMACforAmerica , #AMACforA...
# 22  [A $15 minimum wage is good for working people...
# 23  [#RedAlert! #NetNeutrality is on life support....
# 24  [Trump's Muslim ban is as dangerous as it is w...
# 25  [Alzheimer's disease impacts our families, our...
# 26  [@RepCurbelo A tax on medical devices is a tax...
# 27  [Thank you @RepJohnKatko for talking transport...
# 28  [Do your part to stop the spread of #COVID19 i...
# 29  [Trump's #TitleX gag rule is an attack on wome...
# 30  [@kingjayy305 Caring for Texans is more import...
# 31  [Nurses across the country agree that the admi...
# 32  [👏 That's why we will always #Fight4HER , #Fig...
# 33  [There's still time to stop the #GOPTaxScam. T...
# 34  [The new Puerto Rico fiscal plan must result i...
# 35  [What Trump Must Do in His Senate Impeachment ...
# 36  [Postmaster General Louis DeJoy has repeatedly...
# 37  [The fight is FAR from over. Tell Congress now...
# 38  [@RepJohnLarson Thank you for supporting Ameri...
# 39  [Lift the Harmful, Failing Federal Ban on Spor...
# 40  [Stopping Assisted Suicide in Your State  #Ass...
# 41  [NTU urges all House members to vote "YES" on ...
# 42  [AFLCIOLatino: Felices fiestas! Seguiremos en ...
# 43  [#USMCA will support U.S. farmers by helping t...
# 44  [#YourCarYourData | AIA Canada joins the Your ...
# 45  [AdvaMed Statement on Nomination of Alex Azar ...
# 46  [ATR Supports Equal Act , ATR Supports the STA...
# 47  [Culinary226: Culinary Union members are phone...
# 48               [#PassPHIT , #PassPHIT , #PassPHIT ]
# 49  [Occupational licensing is doing more harm tha...

# %%
# reduce topics to 30
topic_model_30 = copy.deepcopy(topic_model)
topic_model_30.reduce_topics(docs, nr_topics=30)
topic_model_30.get_topic_info()
# Out:
#     Topic   Count                                            Name  \
# 0      -1  160557                -1_workers_twitter_need_congress
# 1       0   66552                     0_medicaid_care_covid19_aca
# 2       1   30320          1_climate_infrastructure_budget_energy
# 3       2   28179         2_daca_immigrants_educators_rweingarten
# 4       3   25047             3_abortion_prolife_parenthood_women
# 5       4   23084                         4_lgbtq_hrc_trans_women
# 6       5   19171                   5_vote_georgia_veterans_thank
# 7       6   12323              6_kavanaugh_supreme_judges_barrett
# 8       7   12094           7_naacp_doj_gunviolence_vanitaguptacr
# 9       8   11543                      8_taxes_cuts_device_reform
# 10      9    9934     9_socialsecurity_benefits_medicare_retirees
# 11     10    7089         10_unemployment_snap_families_childcare
# 12     11    6186              11_cigarettes_products_vaping_kids
# 13     12    5321        12_amacforamerica_democracy_israel_trump
# 14     13    3192        13_diplomacy_northkorea_weapons_irandeal
# 15     14    2741                    14_netneutrality_fcc_data_5g
# 16     15    2402                 15_wage_minimum_15_raisethewage
# 17     16    2019               16_alpa_workers_culinary226_pilot
# 18     17    1477                  17_masks_wear_spread_customers
# 19     18    1385             18_texans_studied_caring_leadership
# 20     19    1195  19_honor_reprorights_popconnect_trumpglobalgag
# 21     20     931              20_usps_postmaster_louis_governors
# 22     21     860               21_pork_wasteful_congress_earmark
# 23     22     698               22_sportsbetting_stadiums_ban_aga
# 24     23     580        23_euthanasia_physician_hotline_national
# 25     24     513                    24_los_una_más_mamasconpoder
# 26     25     354               25_secretary_lilly_hhsgov_insulin
# 27     26     334                    26_atr_coalition_act_opposes
# 28     27     314                 27_passphit_thesfia_fitness_act
# 29     28     303             28_licenses_ohio_hair_freedomtowork
#
#                                        Representation  \
# 0   [workers, twitter, need, congress, support, ta...
# 1   [medicaid, care, covid19, aca, congress, cover...
# 2   [climate, infrastructure, budget, energy, cong...
# 3   [daca, immigrants, educators, rweingarten, dre...
# 4   [abortion, prolife, parenthood, women, hyde, r...
# 5   [lgbtq, hrc, trans, women, union, discriminati...
# 6   [vote, georgia, veterans, thank, today, rosean...
# 7   [kavanaugh, supreme, judges, barrett, nominees...
# 8   [naacp, doj, gunviolence, vanitaguptacr, floyd...
# 9   [taxes, cuts, device, reform, gop, repealdevic...
# 10  [socialsecurity, benefits, medicare, retirees,...
# 11  [unemployment, snap, families, childcare, paid...
# 12  [cigarettes, products, vaping, kids, menthol, ...
# 13  [amacforamerica, democracy, israel, trump, ban...
# 14  [diplomacy, northkorea, weapons, irandeal, yem...
# 15  [netneutrality, fcc, data, 5g, consumers, ajit...
# 16  [wage, minimum, 15, raisethewage, fightfor15, ...
# 17  [alpa, workers, culinary226, pilot, airlines, ...
# 18  [masks, wear, spread, customers, covid19, mand...
# 19  [texans, studied, caring, leadership, hospital...
# 20  [honor, reprorights, popconnect, trumpglobalga...
# 21  [usps, postmaster, louis, governors, saveusps,...
# 22  [pork, wasteful, congress, earmark, govwaste, ...
# 23  [sportsbetting, stadiums, ban, aga, paspa, geo...
# 24  [euthanasia, physician, hotline, national, sui...
# 25  [los, una, más, mamasconpoder, earlyedchat, fa...
# 26  [secretary, lilly, hhsgov, insulin, pharma, ex...
# 27  [atr, coalition, act, opposes, lawmakers, repe...
# 28  [passphit, thesfia, fitness, act, inactivity, ...
# 29  [licenses, ohio, hair, freedomtowork, barriers...
#
#                                   Representative_Docs
# 0   [The opportunity to join a union—no matter whe...
# 1   [#Medicaid is proven to lift millions of peopl...
# 2   [#InfrastructureIsCalling. Working people are ...
# 3   [Tomorrow at 6PM -> Rights of Immigrant Studen...
# 4   [Abortion is violence., BREAKING: House passes...
# 5   [LGBTQ+ rights are human rights. The House jus...
# 6   [Be an early voter in Georgia! Take part in th...
# 7   [The stakes with this nomination are too high....
# 8   [Watch Kristen Clarke explain the moment she k...
# 9   [@VernBuchanan A tax on medical devices is a t...
# 10  [Donald Trump has promised to permanently "ter...
# 11  ["Without #SNAP in place to support families, ...
# 12  [A great thread from @drkellyhenning on the wo...
# 13  [AMAC has long recognized the support of our c...
# 14  [Only #diplomacy is going to prevent war with ...
# 15  [The FTC has jurisdiction over broadband and t...
# 16  [A $15 minimum wage is good for working people...
# 17  [Senator @EdMarkey—we appreciate your support ...
# 18  [Do your part to stop the spread of #COVID19 i...
# 19  [@MillerMonster Caring for Texans is more impo...
# 20        [💚💚💚 #fight4HER , #Fight4HER , #Fight4Her ]
# 21  [Postmaster Louis DeJoy has caused immense har...
# 22  [The fight is FAR from over. Tell Congress now...
# 23  [Our newly released research found overwhelmin...
# 24  [Suicide prevention leader opposes legalizing ...
# 25  [Le agradecemos mucho al Ministro @RubinsteinO...
# 26  [Alex Azar, during hearings for his nomination...
# 27  [ATR Supports the Freedom for Families Act , A...
# 28               [#PassPHIT , #PASSPHIT , #PassPHIT ]
# 29  ["Occupational licensing is a big reason the p...

# %%
# reduce topics to 20
topic_model_20 = copy.deepcopy(topic_model)
topic_model_20.reduce_topics(docs, nr_topics=20)
topic_model_20.get_topic_info()
# Out:
#     Topic   Count                                            Name  \
# 0      -1  160557               -1_workers_twitter_trump_congress
# 1       0   92533                     0_abortion_care_covid19_aca
# 2       1   65588             1_congress_schools_climate_families
# 3       2   28436                       2_lgbtq_hrc_workers_trans
# 4       3   19171                   3_vote_georgia_thank_veterans
# 5       4   17415            4_civil_justice_amacforamerica_naacp
# 6       5   12323              5_kavanaugh_supreme_judges_barrett
# 7       6   11543                      6_taxes_cuts_device_reform
# 8       7    9934     7_socialsecurity_benefits_medicare_retirees
# 9       8    6186              8_cigarettes_products_youth_vaping
# 10      9    3192               9_diplomacy_aumf_weapons_irandeal
# 11     10    3044          10_netneutrality_fcc_privacy_licensing
# 12     11    1477                  11_masks_spread_stores_covid19
# 13     12    1385               12_texans_caring_senior_hospitals
# 14     13    1195  13_honor_reprorights_popconnect_trumpglobalgag
# 15     14     860               14_pork_pigbook_congress_wasteful
# 16     15     698               15_sportsbetting_stadiums_ban_aga
# 17     16     513                    16_los_una_más_mamasconpoder
# 18     17     334                    17_atr_coalition_act_opposes
# 19     18     314                 18_passphit_thesfia_fitness_act
#
#                                        Representation  \
# 0   [workers, twitter, trump, congress, support, t...
# 1   [abortion, care, covid19, aca, congress, twitt...
# 2   [congress, schools, climate, families, daca, i...
# 3   [lgbtq, hrc, workers, trans, union, discrimina...
# 4   [vote, georgia, thank, veterans, today, congre...
# 5   [civil, justice, amacforamerica, naacp, doj, n...
# 6   [kavanaugh, supreme, judges, barrett, senate, ...
# 7   [taxes, cuts, device, reform, gop, repealdevic...
# 8   [socialsecurity, benefits, medicare, retirees,...
# 9   [cigarettes, products, youth, vaping, menthol,...
# 10  [diplomacy, aumf, weapons, irandeal, yemencant...
# 11  [netneutrality, fcc, privacy, licensing, data,...
# 12  [masks, spread, stores, covid19, mandate, dist...
# 13  [texans, caring, senior, hospitals, trauma, vo...
# 14  [honor, reprorights, popconnect, trumpglobalga...
# 15  [pork, pigbook, congress, wasteful, earmark, g...
# 16  [sportsbetting, stadiums, ban, aga, paspa, geo...
# 17  [los, una, más, mamasconpoder, earlyedchat, fa...
# 18  [atr, coalition, act, opposes, lawmakers, repe...
# 19  [passphit, thesfia, fitness, act, inactivity, ...
#
#                                   Representative_Docs
# 0   [Are you ready to stand against rich and power...
# 1   [Congress can't let the president undermine th...
# 2   ["I am very concerned about what is going to b...
# 3   [The #EqualityAct would protect: 🗂4 million+ L...
# 4   [.@POTUS is right: For "We the People," for ou...
# 5   [Together with President Biden and Attorney Ge...
# 6   [With Trump in the White House and Brett Kavan...
# 7   [@RepStephenLynch A tax on medical devices is ...
# 8   [Our Social Security system is vital in ensuri...
# 9   [#Minnesota cities are acting to reduce tobacc...
# 10  [Congress has to support #Diplomacy with #Nort...
# 11  [Rural Americans can't access broadband-qualit...
# 12  [Wear a mask, save a life. , Whenever you're o...
# 13  [@Info_Data_Mgmt Caring for Texans is more imp...
# 14  [#Fight4HER , #Fight4Her , 👏 That's why we wil...
# 15  [Call Congress right now. Tell your Rep to vot...
# 16  [Lift the Harmful, Failing Federal Ban on Spor...
# 17  [Le agradecemos mucho al Ministro @RubinsteinO...
# 18  [ATR Supports Equal Act , ATR Supports the FAI...
# 19               [#PassPHIT , #PassPHIT , #PassPHIT ]

# %% [markdown]
# ## now reduce outliers

# %%
topic_model_50.vectorizer_model
# Out:
# CountVectorizer(stop_words='english')

# %%
# chaining some outlier reduction methods. with only distributions, 387 are left as outliers
new_topics_50 = topic_model_50.reduce_outliers(documents=docs, topics=topic_model_50.topics_, strategy="distributions")
new_topics_50 = topic_model_50.reduce_outliers(documents=docs, topics=new_topics_50, strategy="embeddings", embeddings=embeddings, threshold=.1)

#update topics. ensure vectorizor model is included to stop stopwords from reappearing
topic_model_50.update_topics(docs, topics=new_topics_50, vectorizer_model=topic_model_50.vectorizer_model)
# update frequencies
documents_outlierreduction_50 = pd.DataFrame({"Document": docs, "Topic": new_topics_50})
topic_model_50._update_topic_size(documents_outlierreduction_50)
# view
topic_model_50.get_topic_info()
# Out:
# 2024-10-24 19:42:24,651 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#     Topic  Count                                               Name  \
# 0       0  67674                         0_health_care_medicaid_aca
# 1       1  34230             1_climate_infrastructure_budget_change
# 2       2  29341                        2_abortion_life_prolife_pro
# 3       3  25259                        3_covid19_covid_19_pandemic
# 4       4  19787                         4_lgbtq_hrc_equality_trans
# 5       5  15855                5_schools_students_education_school
# 6       6  24928                  6_thank_support_congress_senators
# 7       7  15879                    7_kavanaugh_court_supreme_brett
# 8       8  12695          8_immigration_immigrants_border_immigrant
# 9       9  11204          9_security_social_socialsecurity_medicare
# 10     10  16955                        10_tax_taxreform_taxes_cuts
# 11     11  11627                       11_gun_violence_civil_police
# 12     12  19920                      12_vote_voting_election_voter
# 13     13  20692                    13_workers_union_unions_working
# 14     14  13480                 14_families_food_work_unemployment
# 15     15   6699             15_tobacco_cigarettes_products_smoking
# 16     16   5429                  16_daca_dreamers_ahca_dreamactnow
# 17     17   7977                       17_racism_black_racial_white
# 18     18   4732                       18_trade_nafta_tariffs_china
# 19     19   4585                       19_war_diplomacy_yemen_peace
# 20     20   7779               20_amacforamerica_democracy_new_amac
# 21     21   4181                      21_wage_minimum_15_fightfor15
# 22     22   3043            22_internet_broadband_netneutrality_fcc
# 23     23   4117                  23_religious_muslim_ban_christian
# 24     24   3929  24_disabilities_disability_advocateforarthriti...
# 25     25   3870                       25_medical_repeal_device_tax
# 26     26   2629               26_aviation_pilots_wearealpa_airline
# 27     27   2093                         27_mask_masks_wear_wearing
# 28     28   2972                           28_gag_rule_title_titlex
# 29     29   3031                      29_texas_texans_option_txlege
# 30     30   3890               30_rule_charge_proposed_publiccharge
# 31     31   4072                    31_fight_fight4her_endalz_thank
# 32     32   1400   32_goptaxscam_goptaxplan_goptaxbill_corporations
# 33     33   1187                33_puerto_puertorico_rico_hurricane
# 34     34   2630             34_impeachment_trump_president_mueller
# 35     35   1690           35_usps_postal_service_savethepostoffice
# 36     36   1245        36_earmarks_noearmarks_pork_earmarkoftheday
# 37     37   4373           37_supporting_commitment_thank_employers
# 38     38   1421          38_taxpayers_sports_sportsbetting_betting
# 39     39    770     39_suicide_assisted_euthanasia_assistedsuicide
# 40     40   1328          40_ntu_coalition_freedomworks_taxreformer
# 41     41    830                                    41_la_que_el_en
# 42     42    757                       42_usmca_trade_mexico_canada
# 43     43   1226                        43_data_auto_drivers_repair
# 44     44    934                         44_azar_alex_secretary_hhs
# 45     45    781                    45_atr_supports_urges_coalition
# 46     46    680           46_culinary226_culinary_unitehere_nevada
# 47     47    369                 47_passphit_phit_phitact_phitday17
# 48     48    523             48_licensing_occupational_ohio_license
#
#                                        Representation  \
# 0   [health, care, medicaid, aca, coverage, health...
# 1   [climate, infrastructure, budget, change, gove...
# 2   [abortion, life, prolife, pro, planned, parent...
# 3   [covid19, covid, 19, pandemic, vaccine, corona...
# 4   [lgbtq, hrc, equality, trans, transgender, wom...
# 5   [schools, students, education, school, teacher...
# 6   [thank, support, congress, senators, members, ...
# 7   [kavanaugh, court, supreme, brett, judge, stop...
# 8   [immigration, immigrants, border, immigrant, c...
# 9   [security, social, socialsecurity, medicare, b...
# 10  [tax, taxreform, taxes, cuts, reform, gop, mid...
# 11  [gun, violence, civil, police, rights, justice...
# 12  [vote, voting, election, voter, voters, georgi...
# 13  [workers, union, unions, working, labor, 1u, u...
# 14  [families, food, work, unemployment, snap, chi...
# 15  [tobacco, cigarettes, products, smoking, flavo...
# 16  [daca, dreamers, ahca, dreamactnow, congress, ...
# 17  [racism, black, racial, white, naacp, hate, ju...
# 18  [trade, nafta, tariffs, china, steel, american...
# 19  [war, diplomacy, yemen, peace, iran, northkore...
# 20  [amacforamerica, democracy, new, amac, biden, ...
# 21  [wage, minimum, 15, fightfor15, raisethewage, ...
# 22  [internet, broadband, netneutrality, fcc, priv...
# 23  [religious, muslim, ban, christian, freedom, f...
# 24  [disabilities, disability, advocateforarthriti...
# 25  [medical, repeal, device, tax, repealdevicetax...
# 26  [aviation, pilots, wearealpa, airline, alpa, w...
# 27  [mask, masks, wear, wearing, customers, stores...
# 28  [gag, rule, title, titlex, sexual, global, ass...
# 29  [texas, texans, option, txlege, senior, leader...
# 30  [rule, charge, proposed, publiccharge, public,...
# 31  [fight, fight4her, endalz, thank, standing, ho...
# 32  [goptaxscam, goptaxplan, goptaxbill, corporati...
# 33  [puerto, puertorico, rico, hurricane, maria, r...
# 34  [impeachment, trump, president, mueller, inves...
# 35  [usps, postal, service, savethepostoffice, dej...
# 36  [earmarks, noearmarks, pork, earmarkoftheday, ...
# 37  [supporting, commitment, thank, employers, ame...
# 38  [taxpayers, sports, sportsbetting, betting, st...
# 39  [suicide, assisted, euthanasia, assistedsuicid...
# 40  [ntu, coalition, freedomworks, taxreformer, ur...
# 41  [la, que, el, en, los, para, las, es, concurs,...
# 42  [usmca, trade, mexico, canada, farmers, agreem...
# 43  [data, auto, drivers, repair, car, autocareorg...
# 44  [azar, alex, secretary, hhs, saynotoazar, hhsg...
# 45  [atr, supports, urges, coalition, act, tax, le...
# 46  [culinary226, culinary, unitehere, nevada, uni...
# 47  [passphit, phit, phitact, phitday17, thesfia, ...
# 48  [licensing, occupational, ohio, license, licen...
#
#                                   Representative_Docs
# 0   [Thanks to the ACA's #Medicaid expansion, thou...
# 1   [If @JoeBiden's $4 trillion infrastructure pac...
# 2   [For those who claim Planned Parenthood isn't ...
# 3   [COVID-19 has disproportionately impacted comm...
# 4   [AlphonsoDavid: For far too long, anti-LGBTQ p...
# 5   [AFSCME: We stand in solidarity with over 30,0...
# 6   [As veterans, we dedicated our lives to this c...
# 7   [An increasing number of Americans don't want ...
# 8   [Immigration has been a major topic of debate ...
# 9   [Social Security is more important than ever. ...
# 10  [Making the Tax Code Great Again  #taxreform, ...
# 11  [The Senate needs to immediately confirm Krist...
# 12  [🚨GEORGIA🚨 We've got just 20 days until electi...
# 13  [We won’t stop fighting until all working peop...
# 14  [Everyone should have food on the table. The 3...
# 15  [After years of Big Tobacco marketing flavored...
# 16  [#DACA recipients are members of our communiti...
# 17  [Today and every day, we stand with the global...
# 18  [Don't believe everything you read about trade...
# 19  [The U.S. has to open up to #diplomacy with #N...
# 20  [#AMACforAmerica , #AMACforAmerica , #AMACforA...
# 21  [A $15 minimum wage is good for working people...
# 22  [#RedAlert! #NetNeutrality is on life support....
# 23  [Trump's Muslim ban is as dangerous as it is w...
# 24  [Alzheimer's disease impacts our families, our...
# 25  [@RepCurbelo A tax on medical devices is a tax...
# 26  [Thank you @RepJohnKatko for talking transport...
# 27  [Do your part to stop the spread of #COVID19 i...
# 28  [Trump's #TitleX gag rule is an attack on wome...
# 29  [@kingjayy305 Caring for Texans is more import...
# 30  [Nurses across the country agree that the admi...
# 31  [👏 That's why we will always #Fight4HER , #Fig...
# 32  [There's still time to stop the #GOPTaxScam. T...
# 33  [The new Puerto Rico fiscal plan must result i...
# 34  [What Trump Must Do in His Senate Impeachment ...
# 35  [Postmaster General Louis DeJoy has repeatedly...
# 36  [The fight is FAR from over. Tell Congress now...
# 37  [@RepJohnLarson Thank you for supporting Ameri...
# 38  [Lift the Harmful, Failing Federal Ban on Spor...
# 39  [Stopping Assisted Suicide in Your State  #Ass...
# 40  [NTU urges all House members to vote "YES" on ...
# 41  [AFLCIOLatino: Felices fiestas! Seguiremos en ...
# 42  [#USMCA will support U.S. farmers by helping t...
# 43  [#YourCarYourData | AIA Canada joins the Your ...
# 44  [AdvaMed Statement on Nomination of Alex Azar ...
# 45  [ATR Supports Equal Act , ATR Supports the STA...
# 46  [Culinary226: Culinary Union members are phone...
# 47               [#PassPHIT , #PassPHIT , #PassPHIT ]
# 48  [Occupational licensing is doing more harm tha...

# %%
# reduce outliers
new_topics_30 = topic_model_30.reduce_outliers(documents=docs, topics=topic_model_30.topics_, strategy="distributions")
new_topics_30 = topic_model_30.reduce_outliers(documents=docs, topics=new_topics_30, strategy="embeddings", embeddings=embeddings, threshold=.1)

#update topics. ensure vectorizor model is included to stop stopwords from reappearing
topic_model_30.update_topics(docs, topics=new_topics_30, vectorizer_model=topic_model_30.vectorizer_model)

# update topic frequencies
documents_outlierreduction_30 = pd.DataFrame({"Document": docs, "Topic": new_topics_30})
topic_model_30._update_topic_size(documents_outlierreduction_30)
# view 
topic_model_30.get_topic_info()
# Out:
# 2024-10-24 19:42:40,169 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#     Topic   Count                                            Name  \
# 0       0  102082                 0_health_care_medicaid_patients
# 1       1   43444        1_climate_congress_infrastructure_budget
# 2       2   33948        2_students_schools_education_immigration
# 3       3   31774                     3_abortion_life_prolife_pro
# 4       4   34833                      4_lgbtq_union_hrc_equality
# 5       5   43434                     5_vote_voting_election_make
# 6       6   18095                 6_kavanaugh_court_supreme_brett
# 7       7   19155                    7_justice_violence_civil_gun
# 8       8   21317                      8_tax_taxreform_taxes_cuts
# 9       9   12734       9_security_social_socialsecurity_medicare
# 10     10   15349                     10_families_work_food_child
# 11     11    6745          11_tobacco_cigarettes_products_smoking
# 12     12   14619     12_amacforamerica_president_trump_democracy
# 13     13    4821                    13_war_diplomacy_peace_yemen
# 14     14    3797         14_internet_broadband_netneutrality_fcc
# 15     15    4663                   15_wage_minimum_15_fightfor15
# 16     16    4615            16_workers_aviation_pilots_wearealpa
# 17     17    2282                      17_mask_masks_wear_wearing
# 18     18    3490            18_texas_texans_leadership_important
# 19     19    5552                 19_fight_fight4her_thank_endalz
# 20     20    2196                     20_usps_post_postal_service
# 21     21    1272     21_earmarks_noearmarks_pork_earmarkoftheday
# 22     22    1689       22_taxpayers_sports_sportsbetting_betting
# 23     23     807  23_suicide_assisted_euthanasia_assistedsuicide
# 24     24     893                                 24_la_que_el_en
# 25     25    1085                      25_azar_alex_hhs_secretary
# 26     26    1040                 26_atr_supports_coalition_urges
# 27     27     401              27_passphit_phit_phitact_phitday17
# 28     28     566          28_licensing_occupational_ohio_license
#
#                                        Representation  \
# 0   [health, care, medicaid, patients, healthcare,...
# 1   [climate, congress, infrastructure, budget, go...
# 2   [students, schools, education, immigration, sc...
# 3   [abortion, life, prolife, pro, women, planned,...
# 4   [lgbtq, union, hrc, equality, people, workers,...
# 5   [vote, voting, election, make, voter, today, t...
# 6   [kavanaugh, court, supreme, brett, judge, trum...
# 7   [justice, violence, civil, gun, rights, racism...
# 8   [tax, taxreform, taxes, cuts, repeal, reform, ...
# 9   [security, social, socialsecurity, medicare, b...
# 10  [families, work, food, child, unemployment, sn...
# 11  [tobacco, cigarettes, products, smoking, flavo...
# 12  [amacforamerica, president, trump, democracy, ...
# 13  [war, diplomacy, peace, yemen, iran, northkore...
# 14  [internet, broadband, netneutrality, fcc, priv...
# 15  [wage, minimum, 15, fightfor15, raisethewage, ...
# 16  [workers, aviation, pilots, wearealpa, airline...
# 17  [mask, masks, wear, wearing, customers, spread...
# 18  [texas, texans, leadership, important, hospita...
# 19  [fight, fight4her, thank, endalz, standing, ho...
# 20  [usps, post, postal, service, photoshopped, re...
# 21  [earmarks, noearmarks, pork, earmarkoftheday, ...
# 22  [taxpayers, sports, sportsbetting, betting, ba...
# 23  [suicide, assisted, euthanasia, assistedsuicid...
# 24  [la, que, el, en, los, para, las, es, concurs,...
# 25  [azar, alex, hhs, secretary, price, saynotoaza...
# 26  [atr, supports, coalition, urges, act, letter,...
# 27  [passphit, phit, phitact, phitday17, thesfia, ...
# 28  [licensing, occupational, ohio, license, refor...
#
#                                   Representative_Docs
# 0   [#Medicaid is proven to lift millions of peopl...
# 1   [#InfrastructureIsCalling. Working people are ...
# 2   [Tomorrow at 6PM -> Rights of Immigrant Studen...
# 3   [Abortion is violence., BREAKING: House passes...
# 4   [LGBTQ+ rights are human rights. The House jus...
# 5   [Be an early voter in Georgia! Take part in th...
# 6   [The stakes with this nomination are too high....
# 7   [Watch Kristen Clarke explain the moment she k...
# 8   [@VernBuchanan A tax on medical devices is a t...
# 9   [Donald Trump has promised to permanently "ter...
# 10  ["Without #SNAP in place to support families, ...
# 11  [A great thread from @drkellyhenning on the wo...
# 12  [AMAC has long recognized the support of our c...
# 13  [Only #diplomacy is going to prevent war with ...
# 14  [The FTC has jurisdiction over broadband and t...
# 15  [A $15 minimum wage is good for working people...
# 16  [Senator @EdMarkey—we appreciate your support ...
# 17  [Do your part to stop the spread of #COVID19 i...
# 18  [@MillerMonster Caring for Texans is more impo...
# 19        [💚💚💚 #fight4HER , #Fight4HER , #Fight4Her ]
# 20  [Postmaster Louis DeJoy has caused immense har...
# 21  [The fight is FAR from over. Tell Congress now...
# 22  [Our newly released research found overwhelmin...
# 23  [Suicide prevention leader opposes legalizing ...
# 24  [Le agradecemos mucho al Ministro @RubinsteinO...
# 25  [Alex Azar, during hearings for his nomination...
# 26  [ATR Supports the Freedom for Families Act , A...
# 27               [#PassPHIT , #PASSPHIT , #PassPHIT ]
# 28  ["Occupational licensing is a big reason the p...

# %%
# reduce outliers
new_topics_20 = topic_model_20.reduce_outliers(documents=docs, topics=topic_model_20.topics_, strategy="distributions")
new_topics_20 = topic_model_20.reduce_outliers(documents=docs, topics=new_topics_20, strategy="embeddings", embeddings=embeddings, threshold=.1)

#update topics. ensure vectorizor model is included to stop stopwords from reappearing
topic_model_20.update_topics(docs, topics=new_topics_20, vectorizer_model=topic_model_20.vectorizer_model)

# update topic frequencies
documents_outlierreduction_20 = pd.DataFrame({"Document": docs, "Topic": new_topics_20})
topic_model_20._update_topic_size(documents_outlierreduction_20)
# view 
topic_model_20.get_topic_info()
# Out:
# 2024-10-24 19:42:55,537 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#     Topic   Count                                         Name  \
# 0       0  133404              0_health_care_abortion_medicaid
# 1       1   94641            1_congress_families_need_students
# 2       2   46560                 2_workers_lgbtq_union_people
# 3       3   45047                  3_vote_voting_election_make
# 4       4   28829              4_justice_violence_rights_civil
# 5       5   18872              5_kavanaugh_court_supreme_trump
# 6       6   21846                   6_tax_taxreform_taxes_cuts
# 7       7   13139    7_security_social_socialsecurity_medicare
# 8       8    6915        8_tobacco_cigarettes_products_smoking
# 9       9    5026                  9_war_diplomacy_peace_yemen
# 10     10    4453      10_internet_broadband_netneutrality_fcc
# 11     11    2378                   11_mask_masks_wear_wearing
# 12     12    3728         12_texas_texans_leadership_important
# 13     13    5934            13_fight_thank_fight4her_standing
# 14     14    1379  14_earmarks_noearmarks_pork_earmarkoftheday
# 15     15    2032             15_taxpayers_sports_taxpayer_ban
# 16     16     942                              16_la_el_que_en
# 17     17    1162              17_atr_supports_coalition_urges
# 18     18     411           18_passphit_phit_phitact_phitday17
#
#                                        Representation  \
# 0   [health, care, abortion, medicaid, access, pat...
# 1   [congress, families, need, students, schools, ...
# 2   [workers, lgbtq, union, people, hrc, equality,...
# 3   [vote, voting, election, make, today, voter, t...
# 4   [justice, violence, rights, civil, gun, racism...
# 5   [kavanaugh, court, supreme, trump, brett, judg...
# 6   [tax, taxreform, taxes, cuts, repeal, reform, ...
# 7   [security, social, socialsecurity, medicare, b...
# 8   [tobacco, cigarettes, products, smoking, flavo...
# 9   [war, diplomacy, peace, yemen, iran, congress,...
# 10  [internet, broadband, netneutrality, fcc, priv...
# 11  [mask, masks, wear, wearing, customers, spread...
# 12  [texas, texans, leadership, important, hospita...
# 13  [fight, thank, fight4her, standing, endalz, ho...
# 14  [earmarks, noearmarks, pork, earmarkoftheday, ...
# 15  [taxpayers, sports, taxpayer, ban, sportsbetti...
# 16  [la, el, que, en, los, para, las, es, concurs,...
# 17  [atr, supports, coalition, urges, act, letter,...
# 18  [passphit, phit, phitact, phitday17, thesfia, ...
#
#                                   Representative_Docs
# 0   [Congress can't let the president undermine th...
# 1   ["I am very concerned about what is going to b...
# 2   [The #EqualityAct would protect: 🗂4 million+ L...
# 3   [.@POTUS is right: For "We the People," for ou...
# 4   [Together with President Biden and Attorney Ge...
# 5   [With Trump in the White House and Brett Kavan...
# 6   [@RepStephenLynch A tax on medical devices is ...
# 7   [Our Social Security system is vital in ensuri...
# 8   [#Minnesota cities are acting to reduce tobacc...
# 9   [Congress has to support #Diplomacy with #Nort...
# 10  [Rural Americans can't access broadband-qualit...
# 11  [Wear a mask, save a life. , Whenever you're o...
# 12  [@Info_Data_Mgmt Caring for Texans is more imp...
# 13  [#Fight4HER , #Fight4Her , 👏 That's why we wil...
# 14  [Call Congress right now. Tell your Rep to vot...
# 15  [Lift the Harmful, Failing Federal Ban on Spor...
# 16  [Le agradecemos mucho al Ministro @RubinsteinO...
# 17  [ATR Supports Equal Act , ATR Supports the FAI...
# 18               [#PassPHIT , #PassPHIT , #PassPHIT ]

# %% [markdown]
# Save topics as excel file w/ a sheet for each

# %%
with pd.ExcelWriter("bertopic_new_oct2424/topics_oct2424.xlsx", engine="openpyxl", mode="w") as writer:
    topic_model_50.get_topic_info()[["Topic", "Count", "Representation", "Representative_Docs"]].to_excel(writer, sheet_name="topics_50")
    topic_model_30.get_topic_info()[["Topic", "Count", "Representation", "Representative_Docs"]].to_excel(writer, sheet_name="topics_30")
    topic_model_20.get_topic_info()[["Topic", "Count", "Representation", "Representative_Docs"]].to_excel(writer, sheet_name="topics_20")

# %% [markdown]
# ### visualization of the topics

# %%
topic_model_30.visualize_heatmap(n_clusters=5)

# %%
topic_model_50.visualize_barchart(topics=list(range(0,49)))
